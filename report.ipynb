# %%
import pandas as pd

df = pd.read_csv('./cleaned_data.csv')
df.head(5)
# Out:
#                     Name Manufacturer Brand    Price  Warranty_time  \
# 0       RX570 PowerColor   PowerColor   AMD   600000              0
# 1  RX 6700 XT MECH 2X OC          MSI   AMD  4500000              2
# 2  RX 6700 XT MECH 2X OC          MSI   AMD  4730000             12
# 3         ASRock RX 6800       ASRock   AMD  6450000              0
# 4  MSI RX 6650 XT 8gb OC          MSI   AMD  6000000             34
#
#   Architecture Max_resolution  Base_clock  Boost_clock  Memory_clock  ...  \
# 0      GCN 4.0      4096x2160        1168       1250.0          1750  ...
# 1     RDNA 2.0      7680x4320        2375       2620.0          2000  ...
# 2     RDNA 2.0      7680x4320        2375       2620.0          2000  ...
# 3     RDNA 2.0      7680x4320        1700       2105.0          2000  ...
# 4     RDNA 2.0      4096x2160        2055       2694.0          2190  ...
#
#    Width Height  Bus_interface  TDP  OpenGL      DirectX  IsNew  No_warranty  \
# ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Assuming df is your DataFrame

# Create a subplot with 2 rows and 2 columns
fig = make_subplots(rows=2, cols=2, subplot_titles=['Boost Clock', 'Max Resolution', 'Width', 'Height'])

# Add boxplot for 'Boost_clock' in the first subplot
fig.add_trace(go.Box(y=df['Boost_clock'], name='Boost Clock'), row=1, col=1)

# Add boxplot for 'Max_resolution' in the second subplot
fig.add_trace(go.Box(y=df['Max_resolution'], name='Max Resolution'), row=1, col=2)

# Add boxplot for 'Width' in the third subplot
fig.add_trace(go.Box(y=df['Width'], name='Width'), row=2, col=1)

# Add boxplot for 'Height' in the fourth subplot
fig.add_trace(go.Box(y=df['Height'], name='Height'), row=2, col=2)

# Update layout to prevent overlapping
fig.update_layout(height=600, width=1000)

# Initialize Dash app
app = dash.Dash(__name__)

# Define layout of the dashboard
app.layout = html.Div([
    html.H1("Your Dashboard Title"),
    
    # Add the Plotly figure to the layout
    dcc.Graph(figure=fig),
    
    # Add any other components or controls as needed
])

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
