# %%
import pandas as pd

df = pd.read_csv('./rawdata.csv')
df.head()
# Out:
#    STT                Tên VGA Nhà sản xuất Hãng      Tình trạng      Giá  \
# 0    1       RX570 PowerColor   PowerColor  AMD  Đã qua sử dụng   600000
# 1    2  RX 6700 XT MECH 2X OC          MSI  AMD  Đã qua sử dụng  4500000
# 2    3  RX 6700 XT MECH 2X OC          MSI  AMD  Đã qua sử dụng  4730000
# 3    4         ASRock RX 6800       ASRock  AMD  Đã qua sử dụng  6450000
# 4    5  MSI RX 6650 XT 8gb OC          MSI  AMD  Đã qua sử dụng  6000000
#
#   Chính sách bảo hành  Thời gian bảo hành(tháng) Architecture  \
# 0   Không có bảo hành                          0      GCN 4.0
# 1       Bảo hành hãng                          2     RDNA 2.0
# 2       Bảo hành hãng                         12     RDNA 2.0
# 3   Không có bảo hành                          0     RDNA 2.0
# 4       Bảo hành hãng                         34     RDNA 2.0
#
#   Độ phân giải tối đa   ...  Bus width  Bandwidth  Số nhân  Length  Width  \
# 0            4096x2160  ...        256        224     2048   255.0  137.0
# 1            7680x4320  ...        192        384     2560   247.0  131.0
# 2            7680x4320  ...        192        384     2560   247.0  131.0
# 3            7680x4320  ...        256        512     3840   267.0  120.0
# 4            4096x2160  ...        128      280.3     2048   277.0  130.0
#
#    Height Bus Interface  TDP  OpenGL      DirectX
# 0    47.0  PCIe 3.0 x16  150     4,6           12
# 1    51.0  PCIe 4.0 x16  230     4,6  12 Ultimate
# 2    51.0  PCIe 4.0 x16  230     4,6  12 Ultimate
# 3    40.0  PCIe 4.0 x16  250     4,6  12 Ultimate
# 4    51.0   PCIe 4.0 x8  176     4,6  12 Ultimate
#
# [5 rows x 25 columns]

# %%
columns = ['STT', 'Name', 'Manufacturer', 'Brand', 'Condition', 'Price', 'Warranty_type', 'Warranty_time', 'Architecture', 'Max_resolution', 'Base_clock', 'Boost_clock', 'Memory_clock', 'Memory_size', 'Memory_type', 'Bus_width', 'Bandwidth', 'Cores', 'Length', 'Width', 'Height', 'Bus_interface', 'TDP', 'OpenGL', 'DirectX']
df = df.set_axis(columns, axis=1).drop(columns=['STT'])
df
# Out:
#                                               Name Manufacturer   Brand  \
# 0                                 RX570 PowerColor   PowerColor     AMD
# 1                            RX 6700 XT MECH 2X OC          MSI     AMD
# 2                            RX 6700 XT MECH 2X OC          MSI     AMD
# 3                                   ASRock RX 6800       ASRock     AMD
# 4                            MSI RX 6650 XT 8gb OC          MSI     AMD
# ..                                             ...          ...     ...
# 110                 GIGABYTE RTX 3070 Ti GAMING OC     GIGABYTE  NVIDIA
# 111                    ASUS TUF RTX 4070 GAMING OC         ASUS  NVIDIA
# 112           GIGABYTE RTX 3070 GAMING OC Rev. 2.0     GIGABYTE  NVIDIA
# 113                 ASUS ROG STRIX RTX 3060 GAMING         ASUS  NVIDIA
# 114  GIGABYTE GTX 1650 WindForce OC GDDR6 Rev. 2.0     GIGABYTE  NVIDIA
#
#           Condition     Price      Warranty_type  Warranty_time  Architecture  \
# 0    Đã qua sử dụng    600000  Không có bảo hành              0       GCN 4.0
# 1    Đã qua sử dụng   4500000      Bảo hành hãng              2      RDNA 2.0
# 2    Đã qua sử dụng   4730000      Bảo hành hãng             12      RDNA 2.0
# 3    Đã qua sử dụng   6450000  Không có bảo hành              0      RDNA 2.0
# 4    Đã qua sử dụng   6000000      Bảo hành hãng             34      RDNA 2.0
# ..              ...       ...                ...            ...           ...
# 110             Mới  13890000      Bảo hành hãng             36        Ampere
# 111             Mới  18990000      Bảo hành hãng             36  Ada Lovelace
# 112             Mới  19389000      Bảo hành hãng             36        Ampere
# 113             Mới  12500000      Bảo hành hãng             36        Ampere
# 114             Mới   3989000      Bảo hành hãng             36        Turing
#
#     Max_resolution  Base_clock  ...  Bus_width  Bandwidth  Cores Length  \
# 0        4096x2160        1168  ...        256        224   2048  255.0
# 1        7680x4320        2375  ...        192        384   2560  247.0
# 2        7680x4320        2375  ...        192        384   2560  247.0
# 3        7680x4320        1700  ...        256        512   3840  267.0
# 4        4096x2160        2055  ...        128      280.3   2048  277.0
# ..             ...         ...  ...        ...        ...    ...    ...
# 110      7680x4320        1575  ...        256      608,3   6144  320.0
# 111      7680x4320        1920  ...        192      504,2   5888  301.0
# 112      7680x4320        1500  ...        256        448   5888  286.0
# 113      7680x4320        1320  ...        192        360   3584  200.0
# 114      7680x4320        1410  ...        128        192    896  172.0
#
#      Width Height  Bus_interface  TDP  OpenGL      DirectX
# 0    137.0   47.0   PCIe 3.0 x16  150     4,6           12
# 1    131.0   51.0   PCIe 4.0 x16  230     4,6  12 Ultimate
# 2    131.0   51.0   PCIe 4.0 x16  230     4,6  12 Ultimate
# 3    120.0   40.0   PCIe 4.0 x16  250     4,6  12 Ultimate
# 4    130.0   51.0    PCIe 4.0 x8  176     4,6  12 Ultimate
# ..     ...    ...            ...  ...     ...          ...
# 110  129.0   55.0   PCIe 4.0 x16  290     4,6  12 Ultimate
# 111  139.0   63.0   PCIe 4.0 x16  200     4,6  12 Ultimate
# 112  115.0   51.0   PCIe 4.0 x16  220     4,6  12 Ultimate
# 113  123.0   38.0   PCIe 4.0 x16  170     4,6  12 Ultimate
# 114  122.0   40.0   PCIe 3.0 x16   90     4,6           12
#
# [115 rows x 24 columns]

# %%
import numpy as np

df.replace(['?', '.', '_', '-', '', 'None', 'NULL', 'Not', '|'], np.nan, inplace=True)
df.isnull().sum()
# Out:
# Name               0
# Manufacturer       0
# Brand              0
# Condition          0
# Price              0
# Warranty_type      0
# Warranty_time      0
# Architecture       0
# Max_resolution     1
# Base_clock         0
# Boost_clock        7
# Memory_clock       0
# Memory_size        0
# Memory_type        0
# Bus_width          0
# Bandwidth          0
# Cores              0
# Length             0
# Width              2
# Height            10
# Bus_interface      0
# TDP                0
# OpenGL             0
# DirectX            0
# dtype: int64

# %%
missing_values = df[df.isnull().any(axis=1)]
missing_values
# Out:
#                                                   Name Manufacturer   Brand  \
# 25                                      NVIDIA NVS 310      LeakTek  NVIDIA
# 26                                      NVIDIA NVS 310      LeakTek  NVIDIA
# 27                                      NVIDIA NVS 310      LeakTek  NVIDIA
# 28                                 NVIDIA Quadro M4000      LeakTek  NVIDIA
# 31                                    NVIDIA Tesla K80       NVIDIA  NVIDIA
# 32                                  NVIDIA Quadro 2000       NVIDIA  NVIDIA
# 33                                  NVIDIA Quadro P400      LeakTek  NVIDIA
# 34                                        ASUS GTX 650         Asus  NVIDIA
# 35                                 NVIDIA Quadro K2200       NVIDIA  NVIDIA
# 36                                 NVIDIA Quadro K2000       NVIDIA  NVIDIA
# 95                                 GIGABYTE GT 1030 OC     GIGABYTE  NVIDIA
# 101  MSI GTX 1050 Ti 4GT OCV1 NVIDIA GeForce GTX 10...          MSI  NVIDIA
#
#           Condition    Price       Warranty_type  Warranty_time Architecture  \
# 25   Đã qua sử dụng   250000  Người bán bảo hành              3    Fermi 2.0
# 26   Đã qua sử dụng   400000       Bảo hành hãng             12    Fermi 2.0
# 27   Đã qua sử dụng   150000   Không có bảo hành              0    Fermi 2.0
# 28   Đã qua sử dụng  3300000  Người bán bảo hành              1  Maxwell 2.0
# 31   Đã qua sử dụng  3000000  Người bán bảo hành              1   Kepler 2.0
# 32   Đã qua sử dụng   850000  Người bán bảo hành              1        Fermi
# 33   Đã qua sử dụng   850000  Người bán bảo hành              1       Pascal
# 34   Đã qua sử dụng   550000   Không có bảo hành              0       Kepler
# 35   Đã qua sử dụng  1450000  Người bán bảo hành              3      Maxwell
# 36   Đã qua sử dụng  1000000   Không có bảo hành              0       Kepler
# 95              Mới  2350000       Bảo hành hãng             36       Pascal
# 101             Mới  4659000       Bảo hành hãng             36       Pascal
#
#     Max_resolution  Base_clock  ...  Bus_width  Bandwidth  Cores Length  \
# 25       2560x1600         523  ...         64         14     48  156.0
# 26       2560x1600         523  ...         64         14     48  156.0
# 27       2560x1600         523  ...         64         14     48  156.0
# 28       4096x2160         773  ...        256      192.3   1664  241.0
# 31             NaN         562  ...        768      481.2   4992  267.0
# 32       2560x1600         625  ...        128       41.6    192  178.0
# 33       5120x2880        1228  ...         64      32.06    256  150.0
# 34       2560x1600        1072  ...        128         80    384  198.0
# 35       3840x2160        1046  ...        128      80.19    640  202.0
# 36       2048x1536         954  ...        128         64    384  202.0
# 95       4096x2160        1266  ...         64      48,06    384  168.0
# 101      2560x1600        1341  ...        128      112,1    768  215.0
#
#      Width Height  Bus_interface  TDP  OpenGL  DirectX
# 25    69.0    NaN   PCIe 2.0 x16   20     4,6       12
# 26    69.0    NaN   PCIe 2.0 x16   20     4,6       12
# 27    69.0    NaN   PCIe 2.0 x16   20     4,6       12
# 28   111.0   38.0   PCIe 3.0 x16  120     4,6       12
# 31   111.0   38.0   PCIe 3.0 x16  300     4,6       12
# 32   111.0    NaN   PCIe 2.0 x16   62     4,6       12
# 33    69.0    NaN   PCIe 3.0 x16   30     4,6       12
# 34   111.0    NaN   PCIe 3.0 x16   65     4,6       12
# 35   111.0    NaN   PCIe 2.0 x16   68     4,6       12
# 36   111.0    NaN   PCIe 2.0 x16   51     4,6       12
# 95     NaN    NaN    PCIe 3.0 x4   30     4,6       12
# 101    NaN    NaN   PCIe 3.0 x16   75     4,6       12
#
# [12 rows x 24 columns]

# %%
width_mean = df["Width"].astype("float").mean()
df["Width"].replace(np.nan, width_mean, inplace=True)

height_mean = df["Height"].astype("float").mean()
df["Height"].replace(np.nan, height_mean, inplace=True)

BoostClock_mean = df["Boost_clock"].astype("float").mean()
df["Boost_clock"].replace(np.nan, BoostClock_mean, inplace=True)

# %%
df["Max_resolution"].replace(np.nan, df["Max_resolution"].value_counts().idxmax(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            115 non-null    object
#  1   Manufacturer    115 non-null    object
#  2   Brand           115 non-null    object
#  3   Condition       115 non-null    object
#  4   Price           115 non-null    int64
#  5   Warranty_type   115 non-null    object
#  6   Warranty_time   115 non-null    int64
#  7   Architecture    115 non-null    object
#  8   Max_resolution  115 non-null    object
#  9   Base_clock      115 non-null    int64
#  10  Boost_clock     115 non-null    float64
#  11  Memory_clock    115 non-null    int64
#  12  Memory_size     115 non-null    float64
#  13  Memory_type     115 non-null    object
#  14  Bus_width       115 non-null    int64
#  15  Bandwidth       115 non-null    object
#  16  Cores           115 non-null    int64
#  17  Length          115 non-null    float64
#  18  Width           115 non-null    float64
#  19  Height          115 non-null    float64
#  20  Bus_interface   115 non-null    object
#  21  TDP             115 non-null    int64
#  22  OpenGL          115 non-null    object
#  23  DirectX         115 non-null    object
# dtypes: float64(5), int64(7), object(12)
# memory usage: 21.7+ KB

# %%
df.to_csv('./cleaned_data.csv',index=False)

# %% [markdown]
# Từ đây về sau hình như không ở trong datacleaning nữa

# %%
df1 = pd.get_dummies(df["Condition"])
df1
# Out:
#        Mới  Đã qua sử dụng
# 0    False            True
# 1    False            True
# 2    False            True
# 3    False            True
# 4    False            True
# ..     ...             ...
# 110   True           False
# 111   True           False
# 112   True           False
# 113   True           False
# 114   True           False
#
# [115 rows x 2 columns]

# %%
df.drop('Condition', axis=1, inplace=True)
df['IsNew'] = df1['Mới']
df
# Out:
#                                               Name Manufacturer   Brand  \
# 0                                 RX570 PowerColor   PowerColor     AMD
# 1                            RX 6700 XT MECH 2X OC          MSI     AMD
# 2                            RX 6700 XT MECH 2X OC          MSI     AMD
# 3                                   ASRock RX 6800       ASRock     AMD
# 4                            MSI RX 6650 XT 8gb OC          MSI     AMD
# ..                                             ...          ...     ...
# 110                 GIGABYTE RTX 3070 Ti GAMING OC     GIGABYTE  NVIDIA
# 111                    ASUS TUF RTX 4070 GAMING OC         ASUS  NVIDIA
# 112           GIGABYTE RTX 3070 GAMING OC Rev. 2.0     GIGABYTE  NVIDIA
# 113                 ASUS ROG STRIX RTX 3060 GAMING         ASUS  NVIDIA
# 114  GIGABYTE GTX 1650 WindForce OC GDDR6 Rev. 2.0     GIGABYTE  NVIDIA
#
#         Price      Warranty_type  Warranty_time  Architecture Max_resolution  \
# 0      600000  Không có bảo hành              0       GCN 4.0      4096x2160
# 1     4500000      Bảo hành hãng              2      RDNA 2.0      7680x4320
# 2     4730000      Bảo hành hãng             12      RDNA 2.0      7680x4320
# 3     6450000  Không có bảo hành              0      RDNA 2.0      7680x4320
# 4     6000000      Bảo hành hãng             34      RDNA 2.0      4096x2160
# ..        ...                ...            ...           ...            ...
# 110  13890000      Bảo hành hãng             36        Ampere      7680x4320
# 111  18990000      Bảo hành hãng             36  Ada Lovelace      7680x4320
# 112  19389000      Bảo hành hãng             36        Ampere      7680x4320
# 113  12500000      Bảo hành hãng             36        Ampere      7680x4320
# 114   3989000      Bảo hành hãng             36        Turing      7680x4320
#
#      Base_clock  Boost_clock  ...  Bandwidth  Cores Length  Width Height  \
# 0          1168       1250.0  ...        224   2048  255.0  137.0   47.0
# 1          2375       2620.0  ...        384   2560  247.0  131.0   51.0
# 2          2375       2620.0  ...        384   2560  247.0  131.0   51.0
# 3          1700       2105.0  ...        512   3840  267.0  120.0   40.0
# 4          2055       2694.0  ...      280.3   2048  277.0  130.0   51.0
# ..          ...          ...  ...        ...    ...    ...    ...    ...
# 110        1575       1830.0  ...      608,3   6144  320.0  129.0   55.0
# 111        1920       2550.0  ...      504,2   5888  301.0  139.0   63.0
# 112        1500       1815.0  ...        448   5888  286.0  115.0   51.0
# 113        1320       1837.0  ...        360   3584  200.0  123.0   38.0
# 114        1410       1635.0  ...        192    896  172.0  122.0   40.0
#
#      Bus_interface  TDP  OpenGL      DirectX  IsNew
# 0     PCIe 3.0 x16  150     4,6           12  False
# 1     PCIe 4.0 x16  230     4,6  12 Ultimate  False
# 2     PCIe 4.0 x16  230     4,6  12 Ultimate  False
# 3     PCIe 4.0 x16  250     4,6  12 Ultimate  False
# 4      PCIe 4.0 x8  176     4,6  12 Ultimate  False
# ..             ...  ...     ...          ...    ...
# 110   PCIe 4.0 x16  290     4,6  12 Ultimate   True
# 111   PCIe 4.0 x16  200     4,6  12 Ultimate   True
# 112   PCIe 4.0 x16  220     4,6  12 Ultimate   True
# 113   PCIe 4.0 x16  170     4,6  12 Ultimate   True
# 114   PCIe 3.0 x16   90     4,6           12   True
#
# [115 rows x 24 columns]

# %%
df['Warranty_type'].replace(to_replace=['Không có bảo hành', 'Bảo hành hãng', 'Người bán bảo hành'], value=[0, 1, 2], inplace=True)
df['Warranty_type'].value_counts()
# Out:
# Warranty_type
# 1    79
# 2    19
# 0    17
# Name: count, dtype: int64

# %%
df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# MSI           28
# GIGABYTE      23
# Intel         16
# ASUS           7
# NVIDIA         7
# Asrock         6
# LeakTek        6
# Saphire        4
# Asus           4
# Colorful       3
# ZOTAC          3
# ASRock         2
# PowerColor     2
# asrock         1
# Gigabyte       1
# POWERCOLOR     1
# Sapphire       1
# Name: count, dtype: int64
